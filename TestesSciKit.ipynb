# %% [markdown]
# <a href="https://colab.research.google.com/github/jenifferluz/testesimagem/blob/main/TestesSciKit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Testes utilizando imagem disponibilizada no SciKit, nomeada "Coffee"

# %%
import matplotlib.pyplot as plt
from skimage import data

img = data.coffee()
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# Escala de Cinza

# %%
from skimage.color import rgb2gray

img_cinza = rgb2gray(img)
plt.imshow(img_cinza, cmap=plt.cm.gray)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
print (img)
# Out:
# [[[ 21  13   8]
#   [ 21  13   9]
#   [ 20  11   8]
#   ...
#   [228 182 138]
#   [231 185 142]
#   [228 184 140]]
#
#  [[ 21  13   7]
#   [ 21  13   9]
#   [ 20  14   7]
#   ...
#   [228 182 136]
#   [231 185 139]
#   [229 183 137]]
#
#  [[ 21  14   7]
#   [ 23  13  10]
#   [ 20  14   9]
#   ...
#   [228 182 136]
#   [228 184 137]
#   [229 185 138]]
#
#  ...
#
#  [[189 124  77]
#   [214 155 109]
#   [197 141 100]
#   ...
#   [165  86  37]
#   [161  82  41]
#   [143  67  29]]
#
#  [[207 148 102]
#   [201 142  99]
#   [196 140  97]
#   ...
#   [154  74  37]
#   [147  66  33]
#   [145  65  31]]
#
#  [[197 141 100]
#   [195 137  99]
#   [193 138  98]
#   ...
#   [158  73  38]
#   [144  64  30]
#   [143  60  29]]]
